# %%
#Importing necessary Libraries

from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
api_key = 'AIzaSyAprV2H1k3vS9h4LoZDg1e3ZG86WgzqHGI' #api_key of Youtube from google API console
channel_ids = ['UC8butISFwT-Wl7EV0hUK0BQ',         #Channel id of freeCodeCamp
              'UCsvqVGtbbyHaMoevxPAq9Fg',         #Channel id of Simplilearn
              'UC4MZ7zUHb5eAxU75Dc_nqdQ',         #Channel id of Tiff In Tech
              'UC0RhatS1pyxInC00YKjjBqQ',         #Channel id of GeeksforGeeks
              'UCqO40lbcG_j5R3imKDrYijQ'          #Channel id of The PyCoach
             ]
youtube = build('youtube','v3',developerKey=api_key) #api_service_name = "youtube" api_version = "v3"

# %%
#get_channel_stats is used interact with the YouTube Data API to retrieve statistics for a given YouTube channel

def get_channel_stats(youtube, channel_id):
    
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=channel_ids)
    response = request.execute()
    
    return response

# %%
get_channel_stats(youtube, channel_ids)
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': '_QRfXlHSGxCHXaC6QJ-r-3NLUNY',
#  'pageInfo': {'totalResults': 5, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'ucSigG9i5fVZetkz_e2qq_dGbos',
#    'id': 'UCsvqVGtbbyHaMoevxPAq9Fg',
#    'snippet': {'title': 'Simplilearn',
#     'description': 'Simplilearn is the world’s #1 online Bootcamp and one of the world’s leading certification training providers. Based in San Francisco, California, and Bangalore, India, we provide training in areas where technologies and best practices are changing rapidly, and the demand for qualified candidates significantly exceeds the supply. We have trained over 3,000,000 professionals, have over 2000 qualified trainers on board, and offer over 400 courses with 40 plus global accreditations. With live instructions from leading experts, interactive labs & projects, peer-to-peer collaboration, on-demand lessons, and 24/7 learning support, we provide learners with a comprehensive curriculum at a fraction of the cost of an on-campus program. \n\nFor more information, visit https://www.simplilearn.com/\nOur FREE courses via SkillUp by Simplilearn now come with Completion Certificates! :https://www.simplilearn.com/skillup-free-online-courses\n\n',
#     'customUrl': '@simplilearnofficial',
#     'publishedAt': '2009-10-29T07:21:23Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/7q9t5rjeujEZYqY1xMLn0mvT4Zc6MaZBYgtseDL2_Zh42AOhMze8ep7BUKdR5FnxytMy3csj=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/7q9t5rjeujEZYqY1xMLn0mvT4Zc6MaZBYgtseDL2_Zh42AOhMze8ep7BUKdR5FnxytMy3csj=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/7q9t5rjeujEZYqY1xMLn0mvT4Zc6MaZBYgtseDL2_Zh42AOhMze8ep7BUKdR5FnxytMy3csj=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'Simplilearn',
#      'description': 'Simplilearn is the world’s #1 online Bootcamp and one of the world’s leading certification training providers. Based in San Francisco, California, and Bangalore, India, we provide training in areas where technologies and best practices are changing rapidly, and the demand for qualified candidates significantly exceeds the supply. We have trained over 3,000,000 professionals, have over 2000 qualified trainers on board, and offer over 400 courses with 40 plus global accreditations. With live instructions from leading experts, interactive labs & projects, peer-to-peer collaboration, on-demand lessons, and 24/7 learning support, we provide learners with a comprehensive curriculum at a fraction of the cost of an on-campus program. \n\nFor more information, visit https://www.simplilearn.com/\nOur FREE courses via SkillUp by Simplilearn now come with Completion Certificates! :https://www.simplilearn.com/skillup-free-online-courses\n\n'},
#     'country': 'US'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUsvqVGtbbyHaMoevxPAq9Fg'}},
#    'statistics': {'viewCount': '316926329',
#     'subscriberCount': '3490000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '6959'}},
#   {'kind': 'youtube#channel',
#    'etag': 'BS5wQug4zhQAx8LcuVckp3X0uKk',
#    'id': 'UC4MZ7zUHb5eAxU75Dc_nqdQ',
#    'snippet': {'title': 'Tiff In Tech',
#     'description': 'Tiffany is a software developer who started her career in the modeling & fashion industry.\xa0 Tech can be very overwhelming for many at first as she experienced first hand entering into the industry. Tiff saw a gap to help ease people into what tech has to offer, to improve their day to day lives. She brings value and trust to her audience by maintaining authenticity\xa0through sharing her life through the lens. Her real and candid approach is why she has a very strong engagement with her community. Through sharing her day to day life, she has built a loyal audience that engages with her in tech, fashion, business and many other areas of everyday lifestyle.\n//Tiff\n\nCome say hi on my other social channel: https://www.instagram.com/tiffintech',
#     'customUrl': '@tiffintech',
#     'publishedAt': '2011-03-13T19:44:23Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/MkbhHI1tJM0t0MtedzzDxa8OWhPftvHfmFPN-VwYcvrgXq4iSXYyI4ZLZMOOST6IhhIZsjHUSKk=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/MkbhHI1tJM0t0MtedzzDxa8OWhPftvHfmFPN-VwYcvrgXq4iSXYyI4ZLZMOOST6IhhIZsjHUSKk=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/MkbhHI1tJM0t0MtedzzDxa8OWhPftvHfmFPN-VwYcvrgXq4iSXYyI4ZLZMOOST6IhhIZsjHUSKk=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'Tiff In Tech',
#      'description': 'Tiffany is a software developer who started her career in the modeling & fashion industry.\xa0 Tech can be very overwhelming for many at first as she experienced first hand entering into the industry. Tiff saw a gap to help ease people into what tech has to offer, to improve their day to day lives. She brings value and trust to her audience by maintaining authenticity\xa0through sharing her life through the lens. Her real and candid approach is why she has a very strong engagement with her community. Through sharing her day to day life, she has built a loyal audience that engages with her in tech, fashion, business and many other areas of everyday lifestyle.\n//Tiff\n\nCome say hi on my other social channel: https://www.instagram.com/tiffintech'},
#     'country': 'US'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UU4MZ7zUHb5eAxU75Dc_nqdQ'}},
#    'statistics': {'viewCount': '17783927',
#     'subscriberCount': '330000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '575'}},
#   {'kind': 'youtube#channel',
#    'etag': 'uV6Di053hy67Q7etdOXnE4pG0eM',
#    'id': 'UC8butISFwT-Wl7EV0hUK0BQ',
#    'snippet': {'title': 'freeCodeCamp.org',
#     'description': 'Learn to code for free.',
#     'customUrl': '@freecodecamp',
#     'publishedAt': '2014-12-16T21:18:48Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/APkrFKaqca-xQcJtp1Pqv-APucCa0nToHYGPVT00YBGOSw=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/APkrFKaqca-xQcJtp1Pqv-APucCa0nToHYGPVT00YBGOSw=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/APkrFKaqca-xQcJtp1Pqv-APucCa0nToHYGPVT00YBGOSw=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'freeCodeCamp.org',
#      'description': 'Learn to code for free.'},
#     'country': 'US'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UU8butISFwT-Wl7EV0hUK0BQ'}},
#    'statistics': {'viewCount': '631787183',
#     'subscriberCount': '8730000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '1553'}},
#   {'kind': 'youtube#channel',
#    'etag': 'xAPHF51kHM6wvWYixxsMzM86EGE',
#    'id': 'UC0RhatS1pyxInC00YKjjBqQ',
#    'snippet': {'title': 'GeeksforGeeks',
#     'description': 'Welcome to the official channel of GeeksforGeeks!\n\nOn our channel you will find hundreds of videos that will provide you with the insight and the knowledge to become an efficient coder. \n\nThese videos are inclusive of real life interview experiences of Geeks who are placed in product and service based companies, webinars and workshops with industry experts which are inclusive of a variety of topics pertaining to Computer Science and coding, informative videos and solutions to a variety of subjects and lastly, a music playlist for you Code Jamming sessions!\n\nSo come and make yourself comfortable in a world that always appreciates Geekiness!\n',
#     'customUrl': '@geeksforgeeksvideos',
#     'publishedAt': '2015-06-11T15:27:03Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/APkrFKZjMrx4Pkr0_ZgCnLe2kDYI8K332WXs6lc2yIk5Zw=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/ytc/APkrFKZjMrx4Pkr0_ZgCnLe2kDYI8K332WXs6lc2yIk5Zw=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/ytc/APkrFKZjMrx4Pkr0_ZgCnLe2kDYI8K332WXs6lc2yIk5Zw=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'GeeksforGeeks',
#      'description': 'Welcome to the official channel of GeeksforGeeks!\n\nOn our channel you will find hundreds of videos that will provide you with the insight and the knowledge to become an efficient coder. \n\nThese videos are inclusive of real life interview experiences of Geeks who are placed in product and service based companies, webinars and workshops with industry experts which are inclusive of a variety of topics pertaining to Computer Science and coding, informative videos and solutions to a variety of subjects and lastly, a music playlist for you Code Jamming sessions!\n\nSo come and make yourself comfortable in a world that always appreciates Geekiness!\n'},
#     'country': 'IN'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UU0RhatS1pyxInC00YKjjBqQ'}},
#    'statistics': {'viewCount': '68902382',
#     'subscriberCount': '666000',
#     'hiddenSubscriberCount': False,
#     'videoCount': '2671'}},
#   {'kind': 'youtube#channel',
#    'etag': '4sMkkL3ZifFWdA6HgiC75hm35RQ',
#    'id': 'UCqO40lbcG_j5R3imKDrYijQ',
#    'snippet': {'title': 'The PyCoach',
#     'description': 'I make Python tutorials and give advice to help you learn how to code. The code of the tutorial I make is available on my Github.\n',
#     'customUrl': '@thepycoach',
#     'publishedAt': '2021-10-09T01:56:51.231243Z',
#     'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/RC8fdPs_HFu1YE1L5dzdUgqgGQjYns0c2NErquRMTxzNbJrDfhXPuTfBaGPJdFhiRQJOGHnFwg=s88-c-k-c0x00ffffff-no-rj',
#       'width': 88,
#       'height': 88},
#      'medium': {'url': 'https://yt3.ggpht.com/RC8fdPs_HFu1YE1L5dzdUgqgGQjYns0c2NErquRMTxzNbJrDfhXPuTfBaGPJdFhiRQJOGHnFwg=s240-c-k-c0x00ffffff-no-rj',
#       'width': 240,
#       'height': 240},
#      'high': {'url': 'https://yt3.ggpht.com/RC8fdPs_HFu1YE1L5dzdUgqgGQjYns0c2NErquRMTxzNbJrDfhXPuTfBaGPJdFhiRQJOGHnFwg=s800-c-k-c0x00ffffff-no-rj',
#       'width': 800,
#       'height': 800}},
#     'localized': {'title': 'The PyCoach',
#      'description': 'I make Python tutorials and give advice to help you learn how to code. The code of the tutorial I make is available on my Github.\n'},
#     'country': 'US'},
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUqO40lbcG_j5R3imKDrYijQ'}},
#    'statistics': {'viewCount': '2130365',
#     'subscriberCount': '33800',
#     'hiddenSubscriberCount': False,
#     'videoCount': '70'}}]}

# %% [markdown]
# ## Function to get channel Statistics

# %%
#defining get_channel_stats refering to the parameters mentioned in Youtube API to get the details of the Youtube Channel

def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids))
    response = request.execute()
    
    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'], 
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    Playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
                
    return all_data

# %%
channel_statistics = get_channel_stats(youtube, channel_ids)

# %%
channel_data = pd.DataFrame(channel_statistics)

# %%
channel_data
# Out:
#        Channel_name Subscribers      Views Total_videos  \
# 0  freeCodeCamp.org     8730000  631787183         1553
# 1       The PyCoach       33800    2130365           70
# 2      Tiff In Tech      330000   17783927          575
# 3       Simplilearn     3490000  316926329         6959
# 4     GeeksforGeeks      666000   68902382         2671
#
#                 Playlist_id
# 0  UU8butISFwT-Wl7EV0hUK0BQ
# 1  UUqO40lbcG_j5R3imKDrYijQ
# 2  UU4MZ7zUHb5eAxU75Dc_nqdQ
# 3  UUsvqVGtbbyHaMoevxPAq9Fg
# 4  UU0RhatS1pyxInC00YKjjBqQ

# %%
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers     object
# Views           object
# Total_videos    object
# Playlist_id     object
# dtype: object

# %% [markdown]
# Converting the Data types from Object to numeric

# %%
channel_data['Subscribers'] = pd.to_numeric(channel_data['Subscribers'])
channel_data['Views'] = pd.to_numeric(channel_data['Views'])
channel_data['Total_videos'] = pd.to_numeric(channel_data['Total_videos'])
channel_data.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# Total_videos     int64
# Playlist_id     object
# dtype: object

# %% [markdown]
# ## Plotting a graph of Channel and its Subscribers

# %%
plt = sns.barplot(x='Subscribers',y='Channel_name',data=channel_data)
plt.set(xlabel='Subscribers(in Millions)', ylabel='Channel Name')
plt.set(title='Channel and Subsribers')
# Out:
# [Text(0.5, 1.0, 'Channel and Subsribers')]

# %%
plt = sns.barplot(x='Views',y='Channel_name',data=channel_data)
plt.set(xlabel='Views(in Millions)', ylabel='Channel Name')
plt.set(title='Channel and Views')
# Out:
# [Text(0.5, 1.0, 'Channel and Views')]

# %%
plt = sns.barplot(x='Total_videos',y='Channel_name',data=channel_data)
plt.set(xlabel='Total_videos', ylabel='Channel Name')
plt.set(title='Channel and Videos Posted')
# Out:
# [Text(0.5, 1.0, 'Channel and Videos Posted')]

# %% [markdown]
# ## Scape, Analyze and Visualize Simplilearn YouTube Channel

# %% [markdown]
# ## Function to get video ids of the channels

# %%
#Getting the playlist id of Simplilearn Channel

playlist_id = channel_data.loc[channel_data['Channel_name']=='Simplilearn','Playlist_id'].iloc[0]

# %%
playlist_id
# Out:
# 'UUsvqVGtbbyHaMoevxPAq9Fg'

# %%
#Function to fetch all the video ids of Simplilearn YouTube Channel

def get_video_ids(youtube,playlist_id):
    request = youtube.playlistItems().list(
                  part ='contentDetails',
                  playlistId = playlist_id,
                  maxResults = 50)
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
    
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                          part ='contentDetails',
                          playlistId = playlist_id,
                          maxResults = 50,
                          pageToken = next_page_token)
            response = request.execute()
            
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
                
            next_page_token = response.get('nextPageToken')
    
    return video_ids

# %%
video_ids = get_video_ids(youtube,playlist_id)

# %%
video_ids
# Out:
# ['vq_OxVy9ej4',
#  'sFP0xhRsqxg',
#  'IWavRr_SHhU',
#  'hZ9_3C2wRrM',
#  'znK0F_Q8RqI',
#  'kITl7Plzsy4',
#  'PtTXBlaS4FM',
#  'XhUJoPebRko',
#  'Ug_VxH3XDO8',
#  'EG_dbZ1RUkE',
#  'c2DbYo-DMO8',
#  'dgUyoBP7a1Q',
#  '68Yj7lYBKAc',
#  'mhPzvcpDcsA',
#  'nRlfxboPrpQ',
#  '-XrcFCzHEYo',
#  'olDytOQJoSc',
#  'Ey7CzUB-4ak',
#  'xKvd5a7ep-0',
#  'VP3bZucdyN0',
#  'ISqFq7SHPQI',
#  'd06w1BNMxG4',
#  'r8Onv5dfNYc',
#  'b9eDWBgQi6c',
#  'K6w3c6lJmQI',
#  'zNbXrFGMeV8',
#  '5f1Qp8vG3E4',
#  'KFpxOO7PXFg',
#  'BS0GLQaSGPo',
#  'ljwts47mZSI',
#  'nTxQNBDjqgU',
#  '4a_18_B6FAY',
#  'dpNjVXL8oLs',
#  'UKuqm6OmCRw',
#  'KcmO_X10vgg',
#  'rxgju8kbgjQ',
#  'ceE3gLgzKcc',
#  'xW9M2ViaC3g',
#  'XUVClE6uSxs',
#  'EBPZdFiyz6c',
#  'ZCm8TnGAM5k',
#  'C0pclZ6QTxQ',
#  'pW-0C6MlhaM',
#  '8fRogy0NWKg',
#  'UWf8tD3DBOk',
#  'nIceRpNcOAM',
#  '0WY-k1QDRWo',
#  'VaqGZWSILqA',
#  '0j62bGQfT7Y',
#  'MAZyj8iRS5A',
#  'QW7gUqEUhb4',
#  'N4S_jiM_GEE',
#  'I4sI9_4Vxjg',
#  'YvwBcAzsjwE',
#  'wG5nxThHB-M',
#  'ZHHQ8jyK8-Q',
#  'SNA55_GdbJY',
#  'kKqz0o8Gdzw',
#  'eW8IdVb-OMA',
#  'fx7La4xwL8s',
#  'EfNaaxYJWQU',
#  'bYA9kFE-cRA',
#  'AxYlA70MHqo',
#  'JnlmxK2JoJo',
#  '3Ick2LYNPfc',
#  'vw220_p3bmY',
#  'QZYRMAvaK94',
#  'ArrN4OrSNJI',
#  'ZUdlc5LsmHA',
#  'TnCL4_Vt8Q4',
#  'NBNIsOaYlok',
#  'oKOJO16HKzI',
#  '0DGn8PWc8UY',
#  'HGfj-kj3krI',
#  'qQ5B9qIcevM',
#  'YDxXLwdFwac',
#  'xVb8gjTofWk',
#  'QXxS-M7uTlk',
#  'y4w8X3aM_jk',
#  'ZZSP4EEY1hg',
#  'aW3MnG1JChs',
#  'AUQ-b_L3kgI',
#  'eyL0S-K-iJ8',
#  'vSr2FGr3WkQ',
#  'ncfznAMl3Ps',
#  '2AFpt80qAmE',
#  'CTQLxYiFlC0',
#  '62axXx90pHo',
#  '5DuQrvHBzFY',
#  'Jk5x5fwMgUE',
#  'KWDuMl909YA',
#  'l6n4R-UTE0I',
#  'xREifaqDdZI',
#  'QWY6fosU7LU',
#  'WMwtwsEvQLs',
#  'EUOqpMQLFFg',
#  'SVNGf5VWckY',
#  'OvTLlV2L2CA',
#  'hWiBQ2XU8L8',
#  'wOjDVK5EvFY',
#  '_teOC1EXjpk',
#  'jIVv6ertf8s',
#  '8yXvQ4LcB3o',
#  'OvWGhSGuEKU',
#  'kt6Z606vmNQ',
#  'TcR3152-CKw',
#  'sKU-vWTmhXY',
#  '4lWJ4vowvJA',
#  '31ScpF1UeMU',
#  'c7Mi0Q4mEio',
#  'mwj8Ez1pczQ',
#  'uIISUpdygyA',
#  'aV2e50Clh2s',
#  'IBFrrnec1dE',
#  'AclBFU7MQLg',
#  'sYiPemhYzLQ',
#  'm27BgVyvhXU',
#  'ZZR2wDc6VRg',
#  'Fw2n4xTOHj8',
#  'fRUdZxScTWU',
#  'giCFlBkMA54',
#  'BW8FXfZx0X8',
#  'VeyNkJRarAQ',
#  'RE2ZSjgy3YA',
#  'h93x74KxBrE',
#  'DZAg-VM899c',
#  'FUpazdOXKHI',
#  'w4gjHCsG5cw',
#  '2a2cJUsP8DY',
#  '1c6oOF65Lxc',
#  'kd5lhpd0zZk',
#  'uQC0-qyEJC4',
#  'z4WJ0ANa8GA',
#  't3rqV-oSM6Q',
#  'RRVA5tMyfEY',
#  'UZVxRyXWAOQ',
#  'D5j2KNr3yOY',
#  'r6PTyqNh3i8',
#  '6OIYVZxYDIM',
#  'gxlOYz-m5WE',
#  'NcYHjtV_qFc',
#  'tNIT8wwYHGc',
#  '6kzvn9Nf-Ks',
#  'L9TItwbcsCg',
#  'Bbr7zOyJEOA',
#  'tkW7DVdUOHA',
#  '5dU4lIgoHkA',
#  'lE4iP5ezgz4',
#  '9FJVIWK8kXY',
#  'n3JorkLfoOI',
#  'rSjpIngp2I8',
#  'fQT0NrvMTQ0',
#  'Gkc4I9ETsTM',
#  '34eMNC1Oq2A',
#  'lOP1LKBbi0U',
#  'gaGyNM6PnCM',
#  '2qNYC8WgLQc',
#  'ykrE849Yq68',
#  'dW3TNsaUzOo',
#  'mUjnxW6yZW8',
#  'XlNArN_uBcw',
#  'pVdmA1_MIlU',
#  'J_EfdcCkhaA',
#  'qMuS8T7n25U',
#  'eBA8rl0c5hM',
#  'nCdQCxXMPi4',
#  '1aMRygVWz8s',
#  'wHPA6fRCH24',
#  'yZPf41IlCj8',
#  'dR1eI1wgIJ4',
#  'dzt0AKuoCqo',
#  'YWXQhvtWfsI',
#  'TJs7H-UerLE',
#  'BNHIgUMCn7c',
#  'FWE11etv41E',
#  'xOjV4HLqHkI',
#  'pfgeixWfgps',
#  'c0TGfNqw0ZE',
#  'QCIKHkXPANA',
#  'DS4pJ10-Ppk',
#  '6aWMQoIyKJM',
#  '636DRRxpu3I',
#  'HIshnvEZKbA',
#  'XVtjG4uSuM0',
#  'SR7zMquNjuM',
#  'HjiVUqFFFhc',
#  'bpFjQGCa7Xg',
#  'xnRaiFhXBtI',
#  'CTXqpnE2iX4',
#  'mkfBwhhJ2gs',
#  'KTnN83P3kAs',
#  '7Cq9CUgDudQ',
#  '2GQCF4EZWUc',
#  'eNQ-QDX_K44',
#  'aUA_8HTc-88',
#  'YmbCBaqu-5E',
#  'hd3Psv-k-kg',
#  'BfqBz9SOOQA',
#  'XqW25wWHLw8',
#  'FeDQMhfJnL4',
#  'oeuPgvhA0aQ',
#  'of0JTVZIBbo',
#  'Wr_4geb_G-I',
#  'UvTHAOTePzM',
#  '_kY179wPwPU',
#  '9Q3c16Ig5Zw',
#  'j65ifqmhI_M',
#  'xP_OPVt0Mr0',
#  'MCxlqpL1buM',
#  'xgYfh2UnP7o',
#  '8zIAuDKVqhQ',
#  '9uEBSWSZbjM',
#  'IP8aKK02A9A',
#  'ftJXU-5K3hs',
#  '5GjjimVVnTw',
#  't28I-qnxdm8',
#  'Z_W36X1P3z4',
#  'lrRLM6uIvkw',
#  '-GYD00rBvDs',
#  'vMroCLlDcY4',
#  'hWLmTnzJGGQ',
#  '5NPNZxDVaHg',
#  'd8s3l65TQHI',
#  'jC2po-oyPrU',
#  'stbalwgs5DY',
#  'gDy9RVvSVaQ',
#  'Jsr9L-232OI',
#  'oxoDfBCXLXU',
#  '-5xudpj9U4M',
#  'sb4Bhi756v4',
#  'ty8bEFuVM-I',
#  '6Oj99FtSM5w',
#  '-aQR1fsHQkA',
#  'SMX2_7F-IcQ',
#  'latGex1UnKk',
#  'DrCqxnHGfTw',
#  '2dWcfxicLtU',
#  'MjwLo6d6zqk',
#  'QKmUstaxNEE',
#  'kUIh3elunAo',
#  'E0yGka5WGuM',
#  'e4YZptppksA',
#  'BgR1Vrnov5M',
#  'Zfg3fTvm1n0',
#  'W_KzQEx0tXo',
#  'QIdNy3BwmHQ',
#  'NGdlXLfyrf0',
#  'qjyQehua4ow',
#  'eRTr4qI9Dmw',
#  '8KRozK0kxGw',
#  'm_IFFDQHaP8',
#  '_Q4HQt_Eb2I',
#  '9daqmywStFM',
#  'XhUncXM-wSM',
#  'lziswEp1BbQ',
#  '0Ooa3sXxc8U',
#  '-ZTykFcZK_c',
#  'UE4-x9p-94E',
#  'hU2GwvNqQtY',
#  '7FdgsHXEe4w',
#  's7ZLgRpdGLU',
#  'cHZpEzrgpug',
#  'qfeypSg_uWk',
#  'Y9eNgJXT-Qc',
#  'KOCL2anaifo',
#  'KT5LaSMZfv8',
#  '6o-8iCbScn4',
#  'oEh1fCYd8QM',
#  'VYxViY2agwI',
#  'sFM8qCr4yKo',
#  '3K5HR9ZwKyU',
#  '2eemAtgkFWM',
#  'i3cW7FnNu74',
#  'l8US3vqjO0k',
#  '_ACr_N_prUw',
#  'yXe9BaIycSg',
#  'HCnRxR50j7w',
#  '0WNetG0ZFJw',
#  'gnjyi6kuseg',
#  'W7t_j8e2o2A',
#  'TGpXx8UGzfI',
#  'KuqD_caQZJM',
#  'QbdeIHJuZ4Q',
#  '274SWoZ6OeY',
#  'Lo9fPtum_ZM',
#  'U9tTDFgZzWw',
#  'ehcv9z1CYGs',
#  'PYWVy4eXwDE',
#  'hEG5fU17zvI',
#  'rxwLMm80uKQ',
#  'jqOz4MEwn74',
#  'x4TAEY1r_xc',
#  'MfPqfimyr-M',
#  '4t5JpDBKJ4w',
#  'a1YM4MKyDQo',
#  'HNtsgP6blMg',
#  'DyULlsIG3KE',
#  'v4GJiVjdTWE',
#  'KivYYL9IFVo',
#  'yMD3ge7HamI',
#  'vMlVUbbWs7c',
#  '26U2PChW2_s',
#  'MtxRtw2bfaA',
#  'cit7ofz1XPo',
#  '8AhL-PmNpkw',
#  'AATfK4g2Cms',
#  'nrXOj8K7Qiw',
#  'TPSAvSo4Ui8',
#  'ivmWzO0i1pI',
#  'Tf9lp7_KTqQ',
#  'fpbqpQn3uzs',
#  'kqg-c3ACxgk',
#  'MDMos3CTXP0',
#  'qpRvt6G5SfQ',
#  'eKfR3O0uGIU',
#  '-0SLn44lK5U',
#  'gxeyeNUgB_0',
#  '-58aAPlN1N8',
#  'vQPgEm9jAJI',
#  'WYmFupQOD3U',
#  'c41SUgdnVec',
#  'hRD7GYL7Ve4',
#  'fRF1d2UYFAc',
#  'aUt-iBX4G0o',
#  'VW5jokmbU3M',
#  'bK6umUjd-dI',
#  'WPugO12PZ7M',
#  'imHharbZsQ4',
#  'srJcIYSr34c',
#  'hpPVYUWesws',
#  'fYW1adN74tY',
#  'sqDLPxxErJI',
#  '31CloWbIVn0',
#  'K47_DU_uvFU',
#  'amG1787zYBU',
#  'Ui27AOBVg3s',
#  'LAtbB9-mBag',
#  'isId8sJGyUI',
#  'BzzmPZO0qnY',
#  '8-6ObgSjbGs',
#  'tpDUO-udRaQ',
#  '83T724EWNqY',
#  'hvRgrjCXWjs',
#  'n7vzOdda0uo',
#  'jZ5e6lrBpsY',
#  'YoyKC-R_joQ',
#  'arZBKYwOZmU',
#  'Nl4DhRvszP4',
#  'ltwjZy_toNs',
#  'EC_bKHXGmYs',
#  'OQUUQCaT9ec',
#  'cpDDyCkHh20',
#  'h2y65cu_56Q',
#  'rqaWHFboPvA',
#  'xabD8fOhY10',
#  'ELv2jDvgYkA',
#  'myDjzsPzWdY',
#  'MLBZW6UqFZ8',
#  'tSeooZnBvuM',
#  '1N_1hG7P7Do',
#  'Dau89ALHbVc',
#  'QRs3YcxeU0Q',
#  'EqghcJD5jPs',
#  'YEr1EfINMU0',
#  'sjxWpMT9lu8',
#  '7XZgYy3CMFs',
#  'Ac8AleEURfY',
#  'w_LqqjOsLrk',
#  '8qoPuM_XTBQ',
#  'JVg8d2smoiQ',
#  'OmqAOIgSawg',
#  'KpVaEpgPge0',
#  'KF_0_wY0S_M',
#  'lrG0Y2WQy_s',
#  'Y9I0CpDYC3c',
#  'f461cSmiYR0',
#  'bmYjEX1dxfs',
#  '3LaSrCtIQ6Q',
#  'oxmttz5jjbQ',
#  'Ycoufl10T5A',
#  'EVm1ZFHvud8',
#  'Su1anhN-RAk',
#  'UoN9CvOYCDk',
#  'pMohiDJo24k',
#  't3ggJvMs5d8',
#  '8o2ZdKtuPWk',
#  'bPAb7ctVZTI',
#  'gVlNwX7jiv8',
#  'zzQFP12l2hI',
#  'Hiwh2uc9k1U',
#  'bH42wDyHRzk',
#  '1NKtTFttJSg',
#  '4gVa4gM4muU',
#  'M6UHqiXTjyw',
#  'MgFA98oCANg',
#  'poT7ZuXWW2Q',
#  '6JtJ3xDQFTk',
#  'juhC8KpusFY',
#  'bY1tZ7Ehdqc',
#  '_qS_d_gL6Nw',
#  'LusRWlygGIk',
#  '0UDqtq6SgUg',
#  'VEylyMI9qx0',
#  'fqUfAeSu3ao',
#  '3yNnmXG5DCU',
#  '5ABOjWLMu4c',
#  'o0do5clzmvM',
#  'nM-hu9cP5c8',
#  'jZ2qpNZWZng',
#  'fxW8PSRMjSM',
#  'hcR3KFRUwlU',
#  'FgS7A59nkxw',
#  'izpUNvA-8OE',
#  'w2oyZJiPkMw',
#  'D_hNDC2rMIc',
#  'mfaiBHennnA',
#  'JOsdXLcu3DQ',
#  'm5UtE-AEHLg',
#  'LozXbmyGCXA',
#  '3RlS1-k9fNQ',
#  'wUk4uIsyxiI',
#  '4JMKpGtuYZ4',
#  'WiG8BjZuc6k',
#  'y0g9HHJWg3o',
#  'Zf4EVpGnS4Q',
#  'ArU4ocurZdk',
#  'XCp5-Zboi2Y',
#  'ppXFQSg5ncY',
#  'hIOjouQ-EwM',
#  'eRY9kY-qSwg',
#  '9IkXy_ZAcIw',
#  'DMesb5FS2qM',
#  'bv0sUEHdAl0',
#  'vQPogiX6Yx0',
#  'tYTic4kt9Qc',
#  'UdVz5WeSZ0k',
#  'ufTRNBmUOfw',
#  'ISJ1DDbnjTg',
#  'X-Lfo-_-BlQ',
#  'faKjGSIWjFk',
#  'spT6_9QLdOU',
#  'ppeU00QaiSo',
#  'A5CRSAXLoS4',
#  'Cywn4h-HGZQ',
#  'qJb-Su8hGsc',
#  'cHpdhLbi878',
#  'jqr4tz0IMOY',
#  'lwtV0l809D4',
#  'RHM4IVRB4h8',
#  '_-00CNH3q2U',
#  'ad8jodpgXV0',
#  '2CUzmacGvEU',
#  'J5FAC_v94cc',
#  'h6bs2-CCS4c',
#  'V1lg03ubxD8',
#  'V962wM1uGro',
#  'Tm97hIJJEjA',
#  'Sn8e950eL5s',
#  'KAZYZ44TvMI',
#  'u6j-3kBc3zY',
#  '8ISdHOUcSJo',
#  'O_ewgtHJzeU',
#  'BGal3RUIdkU',
#  'QpFu2ODQrx0',
#  'O2AgPz9FcpI',
#  'WMsAoAfzdJk',
#  'WtuuImR49g4',
#  'ZDZSjG4_rAQ',
#  '8ON249GVD3s',
#  'VMx0uirKMJs',
#  'Pg8DFa7i5SQ',
#  'kdhID50JBEU',
#  'MHSPWePuHS0',
#  'dpAmI0C7IKs',
#  'Asurd09LmCU',
#  '1QoKj6bIPnY',
#  'fe9aqznGZ2U',
#  'DjfpIDkngEU',
#  'QWovDou7IVs',
#  'CzBLfz89_60',
#  'iIGSQEM-fKc',
#  'bVHgiTWKzlM',
#  'bXXKaQB4vTQ',
#  'qOyZn09IJFU',
#  '2rteSDSbsRo',
#  'UUF49Du15T4',
#  'n4ilisfPFQY',
#  'P7OcG8pao8w',
#  'Qf9TU01vaUg',
#  'NERwzQ4YgMc',
#  'MpF1NmhBxJ0',
#  'S-phJAL0ysY',
#  '-vFZGKtf0SE',
#  'bArObJmuomc',
#  'cji_Gb9VjH0',
#  'Ey3pSFxUNt0',
#  '3uITOvrtSeA',
#  'MrtRXjKQcNs',
#  'LK-2V2L-38o',
#  'KDHIZrGxG74',
#  'KJPL9HsAhBU',
#  'cK6Rb7IcePY',
#  'eyEpCNTX_1g',
#  '4CPoquzYh3A',
#  'xt5uduRqMio',
#  'c1bNWEu9NNU',
#  'L-thDF_hr1o',
#  'mHOSiDIzL9k',
#  'MgAyu4ilp68',
#  '_ySOnWbf2l8',
#  'qajA0UDX_Ow',
#  '_YZNYUdS4jY',
#  'SqWo34Y8lBA',
#  'dWRS9GuKnEk',
#  'eaTC5aReb3w',
#  'LXBwkA3yBWE',
#  'hcZRaShbDFQ',
#  'bAD5t660hCw',
#  'BphychxVmV0',
#  'zW9gjkct89Q',
#  '34ZrB8l17p4',
#  'BZULiASQzgQ',
#  'UD_7p-n9Do8',
#  'HNizXXd-PpM',
#  'YzaQcJ5xSTk',
#  'iJ_ndRDNjoc',
#  'seUHYZRpvJw',
#  'RgJ9Kzw0nR0',
#  '9MAr3IDb_lQ',
#  'c_ynSrL44AA',
#  'l7S75MNRZCY',
#  'KJQ6OIm1fTo',
#  '3kqqxsQNy7w',
#  'T7Jsp6NRH54',
#  'xq5rpK473I0',
#  'J9Kh0iH5CUA',
#  '87pQlCMYiMU',
#  'h7LQtoC_1CE',
#  'kX5eZeMy0FU',
#  'rbGm2V2MKz8',
#  'HPqg_gPS_S0',
#  'clOQ_CnP6dw',
#  's_-OXQPidg8',
#  's3gU8OqCd6s',
#  'XMeWuc_ycPQ',
#  'pwnIT0GlJM8',
#  'KksEcDkgkXk',
#  'Sx44K87994Y',
#  'GqVGS-y8YnY',
#  'a990Y0eyFkI',
#  'wg7BmG6sliQ',
#  'dtEk8w1RRGg',
#  'pc-72_JZZHU',
#  'Po092HvGZKU',
#  'zd8V9wxavk0',
#  'nW4DYTh5G4k',
#  'y9mBf3Y2XVQ',
#  'MXv9G2SESzs',
#  'sgaLAPfPHBk',
#  'H6Gwze_8AnU',
#  'D4gMv2YGbaI',
#  'ItI1SOn4U-w',
#  'CBBhyTba_KI',
#  'BAaDULrGt4s',
#  'f2g97g1qYiQ',
#  'NSINM135O7A',
#  'CFv_H6ilDro',
#  'dpI_IOxK1jo',
#  '8jWKak754VQ',
#  'PsnbysnhaiU',
#  '5HdWp0CqBso',
#  'gtbc3XoCdWk',
#  '38RZdFK7Prg',
#  'iVPNdBwqhbY',
#  'rOGE8COlLpw',
#  'tjKw_yF6s5k',
#  'ee0_3A_OJLA',
#  'odSlmIfNswQ',
#  'Bfqu75obvyg',
#  'K2QSQwNpikg',
#  '9Sqfxhx29Xc',
#  'JP-bUTR315M',
#  'h1ys0dIwkgw',
#  'EoJ3G5QZpzw',
#  'LdDNyFHbcDs',
#  '9dX7S-xgS60',
#  'HvA7I0l0nqI',
#  'zIWGjkr0ENE',
#  'f29GlpFKvzA',
#  'LqBr0FayyqE',
#  'RoOKd4DPdeg',
#  'FRpWxaivJ3k',
#  'TglNI4uJ6do',
#  'qniNw6AMfrI',
#  '4zrZ_AoWh90',
#  'Twi29Wme5_8',
#  'lHb2O0XzVTE',
#  'pc8_MSrtVQQ',
#  'Il82d2bAmr0',
#  'zJelJXvqDvI',
#  'lE6CMM7rw8c',
#  'eULw4O2aE-s',
#  'fDHFN9lZUQM',
#  'ODdeM6cgsmM',
#  'ZgFj49xoyc0',
#  'SfEAe-oLj6E',
#  'TQ2ebUvdwsA',
#  'S2gCNQG1lKk',
#  'IScFj2IviKo',
#  'I5Z1hfV_ZKY',
#  'I7KqAEr5ojY',
#  'yF_eZzcVRIQ',
#  'qRiV4xiL-hY',
#  'bBPoU8MXuXY',
#  'fTq464WHmps',
#  'ET3KMw1v1Sw',
#  'KN7E9oGQ81A',
#  'x1ZGaQknaqc',
#  '2ySWl5S7o5Y',
#  'E4lomzutiTM',
#  'FsTnBwZqdM0',
#  'M_Oo35GNP4A',
#  'V6MZr4cP9TA',
#  'ohLAtWDoUzw',
#  '0DLI-kRoFq0',
#  'ivaRdiX2tTg',
#  'drOquGFhroM',
#  'IWYkC6Q1sp0',
#  'CEWGcWLTfsg',
#  'S38eYwF9XKg',
#  'VF56JytCfFI',
#  'faWC3V9-xF8',
#  'YFgJxPhvbWY',
#  'g-h0r85Dp2Y',
#  'No3CYOwCgmA',
#  'IgPij4yFu_0',
#  'pZTziHZpJ9c',
#  'opHoU93lt_8',
#  'gf60isOX8iw',
#  'qxSUAaJtDz8',
#  'Yd5XvDoZvlI',
#  '0tud2Izgq68',
#  'MLGgEGWD9-4',
#  'bLw5MFpUN9k',
#  '9KWAvXFC85o',
#  'GNXkhheZcs0',
#  'DozWj3PBLFc',
#  '3DGIFLLUgWc',
#  'J4E0zEptbA8',
#  '-A4hIL4fkBg',
#  '72qdcBC8PVo',
#  'mGpWh-1orsk',
#  'xQRmc7pNjRE',
#  'chibQ2REwuY',
#  'Sge2cnsL4qI',
#  'XGP1Thwajzg',
#  'vHgS1COT_8c',
#  'fF_3HKC0y-U',
#  'jyYYEgzVYW8',
#  'NRmOPS2cYAM',
#  'AcDfB8ly5KI',
#  '9OGDygEVqVI',
#  'nkM2IY8yu0c',
#  'Z7g2AYVW0Ho',
#  'SVwD687iW5g',
#  'rvnRIgihruA',
#  '3XBSVW6HVYk',
#  'q7f-b8MZwV0',
#  'b7DdJbIr6C0',
#  'lLI4gjk24UE',
#  'i_ceZEHs9Xw',
#  'DtrgybUAHNI',
#  'UFIoGIUh_0E',
#  '-P3_r96smLs',
#  'kHyO6q1LlQU',
#  'jgvFCkvYnQg',
#  'xDocAJFu5B0',
#  'JBcJUl3rbUk',
#  'MlFRrco6xTQ',
#  'kB4JL-BdB0Y',
#  'kLqAGklbmq8',
#  'Qlw1tqY4_vc',
#  'ja61b75Cmf0',
#  'PDhGAsySSE8',
#  '8c9jguniiVI',
#  '5IG8XVV8LLc',
#  'O_YtvIgsnoE',
#  'n03SPZAdPME',
#  '93kscnXxS_Q',
#  'Iv1gwtp6yBU',
#  '_91eE1zJuxc',
#  'ysasgij05gE',
#  'VIUK7rh55RE',
#  'DlynCE_bScc',
#  'HnO-J0Ko3wU',
#  'xYxUAY3uTZU',
#  'ZHdRAPrW8WY',
#  'Hn21vvCBH6Q',
#  'QhzYHNd7JHU',
#  'qG_7tEc7leU',
#  'kP3sbYTdy1U',
#  'DyaImKBQdN8',
#  '2BPXT-djZus',
#  'V9vsFfsRBE0',
#  'jeg6RRPd850',
#  'pLTJyWNY22c',
#  'MQkVIYzpK-Y',
#  '6KZyR1xJvY0',
#  'nT3cvhWT2GQ',
#  'mWOUpRk6BMI',
#  'NBJwKult2pU',
#  'ZsbP3kQBx5I',
#  'cqDJYffvqFE',
#  'SQ001k21p_A',
#  'kvJm9Py7Enc',
#  '_iz3ouik3SA',
#  '9VNHhxRTbSI',
#  'X-GGDjV-dv0',
#  '8Z6XF-PRlxk',
#  'zd8cphMXKZw',
#  'kSGLD65UCGk',
#  '_BvLk3J8nkY',
#  'U1ps7gWNVss',
#  'eGFMpJ5ooEU',
#  'cU_OVmsPruA',
#  'wNe93bsrcf0',
#  'gA2lSSUP4JY',
#  'T4f9fe_tVmA',
#  '061QRJa26kU',
#  'yGSxenFdZAU',
#  'AhzKGkvi4zA',
#  'msywDF5ta1s',
#  '_6kolcHmrMg',
#  'X5T3gN09oEg',
#  'oCu54_9hI0k',
#  '-uPPICyLhrg',
#  'QC2pGuzzf3Y',
#  'AHWX8OsWxw0',
#  '_GHmFU1Bn0Q',
#  'yQIj7tT1rXs',
#  'w8YBNXJ9v8Y',
#  'hH8xE6udEBw',
#  'Zb3Y7Hpur4I',
#  'aL2XMRk_Wxk',
#  '-7pGo-Oe2AQ',
#  '-lhnu_3kGdE',
#  'zaSwTAvnCJk',
#  'HDkKbJSZwZU',
#  'zJTh-4mUqUI',
#  'm9ViGf3iPHo',
#  'IYsD65CnGXA',
#  'B6zGwbW5_Ns',
#  'YThfTKOQoCg',
#  'kjXgYBiOzc4',
#  'wgK4Bn4qmBc',
#  '-Li73c8gHGA',
#  'iS0wYwboiIE',
#  'fB1hqutcFeY',
#  'XGT0FWkCZI0',
#  'WsWS-dFJ1IQ',
#  'F3nV_URmbJ4',
#  '-6IAwzLxZmA',
#  'hNWKzfobhFA',
#  'n63HzToU_4U',
#  'yIGDXzAd9MA',
#  '7xhTPE_ZlY0',
#  'jKihGsmhYsc',
#  'CAS-h5JkWpw',
#  'La-Z6sWy7FQ',
#  's1v5UwM56yM',
#  'NNcBHvzlvJQ',
#  'iMnhzjhkdXM',
#  'B5mDCBUKtJg',
#  'EKdZutMkmTE',
#  '_rCOrDuceRo',
#  '09ThVx2KRfg',
#  'a75Q6dtg1_s',
#  'azaQJ2wJlFM',
#  '9z0BNicnBjw',
#  'RhsgI5Vv7QY',
#  'cBOcsayH4bY',
#  'NZbya61W1-k',
#  'cX_hInhOEe8',
#  'gHWkoUIkMBQ',
#  'o_39R9wuvWA',
#  'qiY9wc9gUwE',
#  '9n0oA3iWSqM',
#  'PuTS9FEGZr0',
#  '_jzSvSk-lX0',
#  'cHaZF59JOQ8',
#  'UF4gFo2t3cQ',
#  '8KeJZBZGtYo',
#  'ulLjGFwFqbs',
#  '9PsieKdbVh8',
#  'DGJkpX5IA04',
#  'ap1DMKl86SA',
#  'mGSAKjnNu6g',
#  'nPh32MRKbT4',
#  'BWYjdbzTA2I',
#  'q_EvK1Ycbek',
#  'HPBzBiLG5Sc',
#  'V4XxCwM1q3A',
#  'pPLqZyGKjno',
#  '5DIUHvR_edk',
#  'mNqA4SHo8zM',
#  'yWvjUncd5sc',
#  'RZeiTLzy5VE',
#  'kJiPcyah75k',
#  'nN0_rs0HZY0',
#  'XGRfldq44Yk',
#  'N1kud997t6A',
#  'wG_p_SoJgIg',
#  'v-EquowEW8c',
#  'oMDIZWXLstI',
#  'S3vBfEUG9Fc',
#  '9vyLDtEtkFI',
#  'pPAOXLTIOVg',
#  'wo7eAB2fYgE',
#  'Vfg7INt_beU',
#  'kieciFcVWRA',
#  'ZjUdnqG8Qrc',
#  '2kVTU4Gaguk',
#  't4YxOEwmjTQ',
#  'uK4IXTX9SgI',
#  'kFh1hy2vKWM',
#  'RhDY2zZ5vcY',
#  'HgpbN0_lOR8',
#  'AQMHHTG2ZXE',
#  'tdV9L3C-hxQ',
#  'YUvPrSAani4',
#  'IkXENHp2jj8',
#  't9Ya1Q9JLlE',
#  'yOXY4p0-FAI',
#  '2d4SU90fP9w',
#  'cKoeD2cSShI',
#  'SDSPpZuILPo',
#  'NnP4SRe6MDc',
#  'yPCbDzZIGT0',
#  'rNFImrEaRB0',
#  '8yCdfQdQMqQ',
#  'AXrptX2_mnA',
#  'NuVAgAgemGI',
#  'ahWe5_Z8upk',
#  'UltXZb8pP_M',
#  '53X83dH7Gk8',
#  'wl-4ZDsnw-s',
#  't3Fm5_3o1pQ',
#  'eKzML6_h_6k',
#  '_LJz_l_MIuY',
#  '762YllAX2ks',
#  '-XSkSWkBBAA',
#  'VTUW4RhqMwU',
#  'yagAG4urhiQ',
#  'MHinBxgEFz8',
#  'yBg2efPmGpU',
#  'dZ8ta-Ivn-s',
#  'RTWLFHbb5HA',
#  'eH_nVTfe6yU',
#  'l9SaVYRqCkw',
#  'qsxs8G-QnFw',
#  'HWecXtwFF4Q',
#  'FNcYRLjc5T4',
#  'LYt4HHDzVTM',
#  'Py305o6uuNo',
#  'P6YltY67tEw',
#  'hPx0EWTd0kM',
#  'DWDImWk-UEs',
#  'AIPjD5DUcsw',
#  '5Kcf9L_nKtc',
#  '1Q47-GXGaPc',
#  'JO0xwm5bdrA',
#  'LKzntCOqeNQ',
#  '8Z629mibMzk',
#  'Hv4QGbvrEio',
#  'PX9vx50OeZQ',
#  'sog7vjshaLQ',
#  'R5QzNQH4Kus',
#  'SIyAxKejg3I',
#  '4-Z7YNnwub4',
#  'm95iSjejpmc',
#  'SSffyoHrjJI',
#  'HClgbixc2E8',
#  'r33tTgNCE-I',
#  '5__-TjSpTKo',
#  'fraBj-BznNo',
#  'ufxkkhdrXvE',
#  'tGt_6uERmMs',
#  'IyH3eSLFK2Q',
#  'XEwfaNKOqJ0',
#  'OhBmSk9kC80',
#  'KOUdL8BYnFw',
#  '6UJk0hEAXrY',
#  '1HpYwa52LeY',
#  'jmZ_feuYnkQ',
#  '_zanLvqYNKI',
#  'vEp8oNMiQb8',
#  '2nkc1X2wTEs',
#  '6LY3qSlqjrs',
#  'gkwqByT4Kmg',
#  'txYMihA89K8',
#  'CJZRhlu6GNw',
#  '7Io1VdngvbY',
#  'xzVX69cPhes',
#  'xXkevJcOBTw',
#  's7g8fZ8dJJo',
#  'JgwyL4IeNMM',
#  'zTATJWOrz6E',
#  '8ZYCpX5vpVo',
#  'rSNFoeCbZIs',
#  'UxA_Dk_-lvw',
#  'MVmTVR1x7IE',
#  '3NDhETVfrp0',
#  'hOqiddLEXgY',
#  'rq_Xl71d3tE',
#  'Rz5PpB_Ga4U',
#  'sPlN6OB8ISY',
#  'jrKsiFvoxOg',
#  'T70pkWAhlwk',
#  '2mXTpWGjNRM',
#  'rG3OgqnJeKo',
#  'HU3J1_Y9Now',
#  '1y7At_so1Tc',
#  '3AcOGl3XNPo',
#  'SubQ6vJBXdk',
#  'tTZiaIjOtOQ',
#  'Dsl-ILWzUHM',
#  '8HrwT0vapIA',
#  'a1ycPlgH7uo',
#  'gD9zydvct2s',
#  'XACY9MUrBcc',
#  'BWHXML7Hqow',
#  'pFtvPB4Ux_8',
#  '1t_yrWuVEJc',
#  'HPbAQwAd_9A',
#  'iQoq_Hk7aI0',
#  'DsDAt96SaAU',
#  'pNMn-0OnjUU',
#  '5FyHrB9xPVA',
#  '0Hf2JeGODBM',
#  'xdYMAylz1iE',
#  'JVGWg7yIztk',
#  'hNNGZQS3NDc',
#  'PhuTOnGmCYE',
#  'UA4DepUCRJE',
#  'O3ShC1ls09o',
#  'M1El35DLKLY',
#  'ft88cStwBUM',
#  'l24vtm7Dzm0',
#  'oHDgTgL1jZQ',
#  'fAYE8i-l1Dk',
#  'lfIybW_vcVY',
#  'qZ8AtqJijrw',
#  'qn1U3oYKBMc',
#  'pSQAFcCooOs',
#  'u9h-DqjSnKA',
#  'yeDy3qD8fn4',
#  'Hew2PwWFniw',
#  'XiVeA5SiDYM',
#  'KIwaGz8htx8',
#  'xNWF3w9dW9E',
#  'KFbbHsRWEx8',
#  'jhRRNiTl3LA',
#  'vrwNdlY31WQ',
#  'dUG8urfLErc',
#  'IJAfZeyceYY',
#  'QFhq3ymA55s',
#  'PZFI0qGjp3o',
#  'bjTxnO-N7R0',
#  'MgWf6k_EMKI',
#  'TylCtuNkMnA',
#  'tJEE4KygzDY',
#  '_uwTnz-3Res',
#  'Q-4jzYIcdxM',
#  'XPIZkboWuTc',
#  'ckuOSGB3c_k',
#  'KOwSBmIBu-Y',
#  'BLr7V3eskg4',
#  'cCsgog-qTGw',
#  'IIFjF0tiE_M',
#  '8XVHftQskxk',
#  'UCJSQ_2rM40',
#  'faBRsREN1Dg',
#  'zKbTT6hX7p0',
#  'kLXFVArm7GY',
#  'lXcO3y_YGOM',
#  'Z4nlV0aFFn8',
#  'Sr6rg6QMVtg',
#  'TXfrcAGVGCE',
#  '2Rp726V4SmU',
#  'v0KCSWAkbD4',
#  'IiP-vQ4ZyMc',
#  'rYUYLSdoH_0',
#  'Ttz27SDh3gg',
#  'pThds6g_MOc',
#  'CPsjWN8_Eeg',
#  'hCsv9B3p7ng',
#  'M7x7sToJ9y0',
#  'pGjQJmX_IfM',
#  'BtfMgbsNzgg',
#  'MXA5-9prLPI',
#  ...]

# %%
#Fetching the channel details of Simplilearn YouTube Channel

def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0,len(video_ids), 50):
        #We want to retrieve both the snippet and statistics parts of the video information. 
        #The 'snippet' part typically contains basic details about the video, 
        #and the 'statistics' part includes information like view counts, like counts, and comment counts.
        request = youtube.videos().list(
                    part='snippet,statistics',
                    id=','.join(video_ids[i:i+50]))
        response = request.execute()
        
        for video in response ['items']:
            video_stats = dict(Title = video['snippet']['title'],
                              Published_date = video['snippet']['publishedAt'],
                              Views = video['statistics']['viewCount'],
                              Likes = video['statistics']['likeCount']
                              )
            all_video_stats.append(video_stats)

    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data
# Out:
#                                                   Title        Published_date  \
# 0     Career Masterclass: Strategies for Leadership ...  2023-12-06T11:57:27Z
# 1     How To Become Business Analyst 2024 | Business...  2023-12-06T11:20:33Z
# 2     🔥 Kali Linux Course 2023 | Kali Linux Tutorial...  2023-12-06T11:11:00Z
# 3     Discovering AI's Application in Executive Deci...  2023-12-06T12:08:40Z
# 4     How To Implement Logistic Regression Using Pyt...  2023-12-06T09:30:18Z
# ...                                                 ...                   ...
# 6962  ISTQB Foundation Exam | Software Testing Train...  2012-05-23T05:22:20Z
# 6963  What is Software Testing? | Agenda of CTFL Tra...  2012-05-23T05:20:00Z
# 6964  What is Software Testing? | CTFL Software Test...  2012-05-23T05:18:51Z
# 6965  Minitab Screen Layout | Minitab Tutorial Onlin...  2012-01-04T05:35:25Z
# 6966  Process Groups And Knowledge Areas | CAPM Cert...  2012-01-02T06:03:37Z
#
#       Views Likes
# 0        74    27
# 1       424    19
# 2       147     8
# 3         0     0
# 4       228    11
# ...     ...   ...
# 6962   6981     4
# 6963   5901     6
# 6964  12802    12
# 6965   9944    13
# 6966   2910    26
#
# [6967 rows x 4 columns]

# %%
#This line converts the 'Published_date' column in your DataFrame to datetime format using the pd.to_datetime function. The format='mixed' parameter suggests that the date format might be mixed or not uniform, and the function will attempt to infer the correct format. The .dt.date part extracts only the date component and assigns it back to the 'Published_date' column.
video_data['Published_date'] = pd.to_datetime(video_data['Published_date'], format='mixed').dt.date
video_data['Views'] = pd.to_numeric(video_data['Views'])
video_data['Likes'] = pd.to_numeric(video_data['Likes'])

video_data
# Out:
#                                                   Title Published_date  Views  \
# 0     Career Masterclass: Strategies for Leadership ...     2023-12-06     74
# 1     How To Become Business Analyst 2024 | Business...     2023-12-06    424
# 2     🔥 Kali Linux Course 2023 | Kali Linux Tutorial...     2023-12-06    147
# 3     Discovering AI's Application in Executive Deci...     2023-12-06      0
# 4     How To Implement Logistic Regression Using Pyt...     2023-12-06    228
# ...                                                 ...            ...    ...
# 6962  ISTQB Foundation Exam | Software Testing Train...     2012-05-23   6981
# 6963  What is Software Testing? | Agenda of CTFL Tra...     2012-05-23   5901
# 6964  What is Software Testing? | CTFL Software Test...     2012-05-23  12802
# 6965  Minitab Screen Layout | Minitab Tutorial Onlin...     2012-01-04   9944
# 6966  Process Groups And Knowledge Areas | CAPM Cert...     2012-01-02   2910
#
#       Likes
# 0        27
# 1        19
# 2         8
# 3         0
# 4        11
# ...     ...
# 6962      4
# 6963      6
# 6964     12
# 6965     13
# 6966     26
#
# [6967 rows x 4 columns]

# %% [markdown]
# ##Top 10 Videos of Simplilearn

# %%
top10_videos = video_data.sort_values(by='Views',ascending=False).head(10)

# %%
top10_videos
# Out:
#                                                   Title Published_date  \
# 3969  Ambition #CannotBeLockedDown ​| Nikhil Got His...     2021-09-14
# 4536  How To Introduce Yourself In Interview | Self ...     2021-03-19
# 5646  Machine Learning | What Is Machine Learning? |...     2018-09-19
# 5598  Data Science In 5 Minutes | Data Science For B...     2018-12-04
# 4968  Digital Marketing In 5 Minutes | What Is Digit...     2020-09-23
# 5263  Digital Marketing Course Part - 1 🔥| Digital M...     2020-03-16
# 3385  Advanced Excel Full Course 2022 | 🔥Advanced Ex...     2022-02-04
# 5164  Cyber Security In 7 Minutes | What Is Cyber Se...     2020-06-10
# 5287  Six Sigma In 9 Minutes | What Is Six Sigma? | ...     2020-02-25
# 5554  Blockchain In 7 Minutes | What Is Blockchain |...     2019-02-27
#
#          Views   Likes
# 3969  18218145     527
# 4536   6530132  126503
# 5646   4132518   51660
# 5598   3735421   53829
# 4968   3594660   81889
# 5263   3525361   82504
# 3385   2892011   42100
# 5164   2421415   49191
# 5287   2395008   47386
# 5554   2386195   38579

# %%
import warnings #importing this library to overcome warnings(cosmetic) that was caused by fire 🔥emoji in the title of the video

warnings.filterwarnings("ignore", category=UserWarning, module="IPython")
ax1 = sns.barplot(x='Views', y='Title', data=top10_videos)
plt.plot([1, 2, 3], [4, 5, 6])

# %%
video_data['Month'] = pd.to_datetime(video_data['Published_date']).dt.strftime('%b')

# %%
video_data
# Out:
#                                                   Title Published_date  Views  \
# 0     Career Masterclass: Strategies for Leadership ...     2023-12-06     74
# 1     How To Become Business Analyst 2024 | Business...     2023-12-06    424
# 2     🔥 Kali Linux Course 2023 | Kali Linux Tutorial...     2023-12-06    147
# 3     Discovering AI's Application in Executive Deci...     2023-12-06      0
# 4     How To Implement Logistic Regression Using Pyt...     2023-12-06    228
# ...                                                 ...            ...    ...
# 6962  ISTQB Foundation Exam | Software Testing Train...     2012-05-23   6981
# 6963  What is Software Testing? | Agenda of CTFL Tra...     2012-05-23   5901
# 6964  What is Software Testing? | CTFL Software Test...     2012-05-23  12802
# 6965  Minitab Screen Layout | Minitab Tutorial Onlin...     2012-01-04   9944
# 6966  Process Groups And Knowledge Areas | CAPM Cert...     2012-01-02   2910
#
#       Likes Month
# 0        27   Dec
# 1        19   Dec
# 2         8   Dec
# 3         0   Dec
# 4        11   Dec
# ...     ...   ...
# 6962      4   May
# 6963      6   May
# 6964     12   May
# 6965     13   Jan
# 6966     26   Jan
#
# [6967 rows x 5 columns]

# %%
video_per_month = video_data.groupby('Month', as_index=False).size()

# %%
video_per_month
# Out:
#    Month  size
# 0    Apr   489
# 1    Aug   634
# 2    Dec   500
# 3    Feb   424
# 4    Jan   479
# 5    Jul   603
# 6    Jun   621
# 7    Mar   490
# 8    May   666
# 9    Nov   727
# 10   Oct   644
# 11   Sep   690

# %% [markdown]
# ##Sorting the months in an Order

# %%
sort_order = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']

# %%
video_per_month.index = pd.CategoricalIndex(video_per_month['Month'], categories=sort_order,ordered = True)

# %%
video_per_month = video_per_month.sort_index() #Overwritting the previous value of video_per_month

# %%
#Plotting Graph for videos per month of SimpliLearn Youtube Channel
ax2 = sns.barplot(x='Month', y='size', data=video_per_month)
